# %%
import sqlite3
connection=sqlite3.connect('library.db')
# query=(
#     """
#     CREATE TABLE books(
#         id INTEGER PRIMARY KEY,
#         name TEXT NOT NULL,
#         author TEXT,
#         price REAL
#         )
#         """
#     )

# QUERY = (
#     """
#     INSERT INTO books(name,author,price)
#     VALUES('csa','rabi',500),
#           ('dsa','hem',600),
#           ('sad','jayram',400)
# """
# )

# query =(
#     """
#       SELECT *FROM books;
#     """
# )

# data = connection.execute(query)
# for i in data:
#     print(i)
# query =(
#     """
#     SELECT*FROM books WHERE author="rabi"
#     """
# )
# data = connection.execute(query)
# for i in data:
#     print(i)

# query =(
#     """
#     UPDATE books
#     SET price =700
#     WHERE author ="rabi"
#     """
# )

# query =(
#     """
#     UPDATE books
#     SET price =700
#     WHERE author ="rabi"
#     """
# )
name='math'
author='ram'
price= 500
query =(
    """
      INSERT INTO books(name,author,price)
      VALUES(?,?,?)
    """
)
connection.execute(query,(name,author,price))
connection.commit()
connection.close()
